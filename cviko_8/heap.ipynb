# %%
class Heap():
    def __init__(self):
        self.heap_list = []

    def get_son(self, index, left=True):
        if left:
            return index * 2 + 1
        
        return index * 2 + 2

    def get_parent(self, index):
        return (index - 1) // 2

    def _swap_elements(self, i_1, i_2):
        self.heap_list[i_1], self.heap_list[i_2] = self.heap_list[i_2], self.heap_list[i_1]
        
    
    def bubble_up(self, index):
        
        while index > 0:
            # compare with parent
            parent = self.__parent(index)
            if self.heap_list[parent] <= self.heap_list[index]:
                break

            # swap with parent
            self._swap_elements(parent, index)
            
            index = parent
            
    def bubble_up_recursive(self, index):
        if index == 0:
            return
        
        parent = self.get_parent(index)
        
        if self.items[parent] <= self.items[index]:
            # swap with parent
            self._swap_elements(parent, index)
            
            # RECURSION STEP
            self.bubble_up_recursive(parent)

    def bubble_down(self, index):
        # TODO implement me
        # hint: look at bubble up implementation
        # hint2: use get_son and _swap_elements method
        
        # bubble down... move an element down until the heap is valid again
        pass

    def insert(self, item):
        # TODO implement me
        pass

    def min(self):
        return self.heap_list[0]

    def extract_min(self):
        # swap min with last
        self._swap_elements(...)
        
        # remove new last (min)
        # TODO
        item = ...

        # bubble down
        # TODO

        return item
    
    # TODO implement __len__, is_empty, delete

# %%
heap = Heap()


for i in range(10, 2, -1):
    heap.insert(i)

print(heap.min())          # 1
print(heap.extract_min())  # 1

print(heap.extract_min())  # 2

heap.insert(1)
print(heap.extract_min())  # 1

print(heap.extract_min())  # 3
